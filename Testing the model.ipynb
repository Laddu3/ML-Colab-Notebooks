# %%
import joblib

model=joblib.load('brain_tumor_kmeans_model.sav')
tumorLabel=4
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-848e0ddf0d17> in <module>()
#       1 import joblib
#       2
# ----> 3 model=joblib.load('brain_tumor_kmeans_model.sav')
#       4 tumorLabel=4
#
# /usr/local/lib/python3.7/dist-packages/joblib/numpy_pickle.py in load(filename, mmap_mode)
#     575             obj = _unpickle(fobj)
#     576     else:
# --> 577         with open(filename, 'rb') as f:
#     578             with _read_fileobject(f, filename, mmap_mode) as fobj:
#     579                 if isinstance(fobj, str):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'brain_tumor_kmeans_model.sav'

# %%
import cv2

imagePath='test.jpg'

imgOriginal=cv2.imread(imagePath)
img=cv2.imread(imagePath,0)
height,width=img.shape
imgFlatten=img.reshape(height*width,1)

# %%
labels=model.predict(imgFlatten)
labels2D=labels.reshape(height,width)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-8924f49f69da> in <module>()
# ----> 1 labels=model.predict(imgFlatten)
#       2 labels2D=labels.reshape(height,width)
#
# NameError: name 'model' is not defined

# %%
mask=(labels2D==tumorLabel)

# %%
import numpy as np

array=np.array([2,547,5,7,87,8,5])
print(array==5)

# %%
tumorExtracted=np.bitwise_and(mask,img)

from matplotlib import pyplot as plt

plt.imshow(tumorExtracted,cmap='gray')
plt.show()

# %%
contours, hierarchy = cv2.findContours(tumorExtracted, cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
print('no. contours:',len(contours))

for cnt in contours:
    #cv2.drawContours(frame, [cnt], 0, (0,255,255), 3)
    area=cv2.contourArea(cnt)
    #print(area)
    if(area>500):

        x,y,w,h = cv2.boundingRect(cnt)
        cv2.rectangle(imgOriginal,(x,y),(x+w,y+h),(0,255,0),2)
        cv2.rectangle(imgOriginal,(x,y),(x+120,y-40),(0,255,0),-1)
        cv2.putText(imgOriginal,"TUMOR",(x+10,y-10),cv2.FONT_HERSHEY_SIMPLEX,1,(255,255,255),2)

# %%
plt.imshow(imgOriginal,cmap='gray')
plt.show()
